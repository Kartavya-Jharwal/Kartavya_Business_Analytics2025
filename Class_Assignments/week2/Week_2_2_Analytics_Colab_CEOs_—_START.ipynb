# %% [markdown]
# <a href="https://colab.research.google.com/github/Kartavya-Jharwal/Kartavya_Business_Analytics2025/blob/main/Analytics_Colab_CEOs_%E2%80%94_START.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fortune Global CEOs - Data Analytics

# %% [markdown]
# ## Import Libraries & Data

# %%
# Import the libraries we'll need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Upload from your computer
from google.colab import files

print("Please upload the Fortune Global CEOs.xlsx file:")
uploaded = files.upload()
# Out:
# Please upload the Fortune Global CEOs.xlsx file:
#      <input type="file" id="files-26c10356-4dac-41e9-8e81-1bace905aac0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26c10356-4dac-41e9-8e81-1bace905aac0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
df = pd.read_excel("Fortune Global CEOs.xlsx")

# %% [markdown]
# # Initial Data Exploration

# %%
# Display basic information about the dataset

# %%
# Get summary statistics

# %%
# Check for missing values in each column

# %% [markdown]
# # Data Cleaning and Preparation

# %%
df_clean = df.copy()

# %%
# Create a new column for CEO tenure
# Note: Some CEOs are still active, so we calculate based on current age

# %%
# For CEOs still active (where 'Age when CEO Tenure Finished' is NaN)

# %%
# Create a column for profit margin (%)

# %%
# Display datafarame

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# 1. Distribution of CEO ages

# %%
# 2. Industry distribution

# %%
# 3. Gender distribution

# %%
# 4. Salary distribution

# %%
# 5. Group by operations
# Average salary by industry

# %%
# 6. Education impact on company performance

# %% [markdown]
# # Business Implication Questions

# %%
# Question 1: Is there a relationship between CEO age at appointment and company profit?

# %%
# Question 2: How does gender distribution vary across industries?

# %%
# Question 3: Top 5 highest-paid CEOs and their companies' profit margins
